# %% [markdown]
# <a href="https://colab.research.google.com/github/devipriya2006/PRODIGY_GA_01/blob/master/genaitask1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Train a GPT-2 model**
#  To generate coherent and contextually relevant text based on a given prompt

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# # Install gpt-2-simple

# %%
# !pip install gpt-2-simple
# Out:
# Collecting gpt-2-simple
#   Downloading gpt_2_simple-0.8.1.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from gpt-2-simple) (2.17.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from gpt-2-simple) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from gpt-2-simple) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gpt-2-simple) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpt-2-simple) (1.26.4)
# Collecting toposort (from gpt-2-simple)
#   Downloading toposort-1.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (1.70.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.5.1->gpt-2-simple) (0.37.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->gpt-2-simple) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->gpt-2-simple) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->gpt-2-simple) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->gpt-2-simple) (2024.12.14)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.5.1->gpt-2-simple) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (0.14.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.5.1->gpt-2-simple) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.5.1->gpt-2-simple) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=2.5.1->gpt-2-simple) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=2.5.1->gpt-2-simple) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=2.5.1->gpt-2-simple) (0.1.2)
# Downloading toposort-1.10-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.8.1-py3-none-any.whl size=24556 sha256=5ae9fb703435308b6547cc457a98d8307769e40cc1552036b3877064c158a2ea
#   Stored in directory: /root/.cache/pip/wheels/9e/59/88/2abf9f043f52307bb3d81010e26ecdb5e539b392e8aca2501f
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.8.1 toposort-1.10

# %% [markdown]
# # import gpt-2-simple

# %%
import gpt_2_simple as gpt2_simple
from datetime import datetime

# %% [markdown]
# # **Loading gpt-2**
# *There* are several sizes of GPT-2:
#
#
# * 124M (default): the "small" model, 500MB on disk.
#
# * 355M (default): the "medium" model, 1.
# 5GB on disk.
#
#
# * 774M (default): the "large" model, 3GB on disk.
#
# Here,i'm using 124M.

# %%
gpt2_simple.download_gpt2(model_name='124M')
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 3.13Git/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.12Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 5.44Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:42, 11.6Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 906Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 2.86Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.46Mit/s]

# %%
from google.colab import files

# %%
gpt2_simple.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sess = gpt2_simple.start_tf_sess()

# %%
# !pip install tensorflow
import tensorflow as tf
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# # **Finetune GPT-2**

# %%
tf.compat.v1.reset_default_graph()
sess = gpt2_simple.start_tf_sess()
gpt2_simple.finetune(sess,dataset='shakespeare.txt',steps=1000, model_name='124M',
                     sample_every=200, save_every=1000,print_every=10,restore_from='fresh' )
# Out:
# Loading checkpoint models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# dataset has 338025 tokens
# Training...
# [10 | 25.79] loss=3.54 avg=3.54
# [20 | 47.51] loss=3.44 avg=3.49
# [30 | 69.51] loss=3.23 avg=3.40
# [40 | 91.80] loss=3.46 avg=3.42
# [50 | 114.23] loss=3.02 avg=3.34
# [60 | 136.83] loss=3.25 avg=3.32
# [70 | 159.58] loss=3.29 avg=3.32
# [80 | 182.41] loss=3.00 avg=3.28
# [90 | 205.31] loss=3.16 avg=3.26
# [100 | 228.26] loss=2.98 avg=3.23
# [110 | 251.29] loss=3.54 avg=3.26
# [120 | 274.41] loss=3.20 avg=3.26
# [130 | 297.58] loss=3.02 avg=3.24
# [140 | 320.80] loss=3.27 avg=3.24
# [150 | 344.11] loss=2.94 avg=3.22
# [160 | 367.47] loss=3.04 avg=3.21
# [170 | 390.81] loss=3.07 avg=3.20
# [180 | 414.12] loss=2.80 avg=3.17
# [190 | 437.41] loss=2.77 avg=3.15
# [200 | 460.72] loss=2.81 avg=3.13
# ======== SAMPLE 1 ========
#  it
# This, in the most gracious favour;
# So in giving, so to speak, of your grace's welcome.
#
# BAPTISTA:
# This is the kind I did not ask.
#
# First Servant:
# Well, gentlemen, how is your honour?
#
# First Servant:
# What's most noble of all dignities
# Is this: the most noble of all lords,
# Who would have them in every borough, was I too.
#
# Third Servant:
# The noble of all lords, who would have any borough,
# If I did have the right of a town too,
# Was myself so noble.
#
# Second Servant:
# The noble of all towns, that do hold an equal place
# That both in regard and condition deserve,
# Is yourself in the best place.
#
# Third Servant:
# It is so.
#
# BAPTISTA:
# How! what doth thy honours?
#
# First Servant:
# I' the most noble, in that wherewithal and courtesy
# I do request.
#
# Second Servant:
# Now, sir, let me go: but first I need not ask
# A single one, for I need hear nothing.
#
# First Servant:
# Sir, if ever this business be so misgoverned,
# I will answer at my pleasure.
#
# Third Servant:
# And then I need not say something: I will attend
# Your guests: then, gentlemen, I hope to hear nothing.
#
# First Servant:
# Then, sir, I hope you will be all right.
#
# Second Servant:
# My honour, what doth my guest need?
#
# COMINIUS:
# But then what doth his benefice need?
#
# Second Servant:
# First, he is in the service of many peers.
#
# First Servant:
# But then he is not like to be a physician,
# His purpose is one one to himself: you, sir, you,
# you fellows that wish him so; so do you gentlemen.
# You are a fellow of honour, sir; if you did not know
# your duty, you should have come to complain.
#
# First Servant:
# So, be it your pleasure, and do so as I say.
#
# Second Servant:
# By your service you do make your guests welcome.
#
# First Servant:
# How can then I complain of no gentleman?
#
# First Servant:
# Sir! if you would not like, you may leave your honours.
#
# Second Servant:
# You may! I hope to hear nothing; you, gentlemen, you, you;
# you, you, you, you fellows that wish you so!
#
# First Servant:
# Then, gentlemen, I hope to hear nothing.
#
# Second Servant:
# You cannot, sir; but, if you would, you might.
#
# Third Servant:
# How, you know me well.
#
# First Servant:
# Sir, I am well, a gentle gentleman?
#
# COMINIUS:
# Most of all, noble,
# your noble lord.
#
# Third Servant:
# A gentleman of your service, sir:
# You know me well; well it may please your lords
# not to have me call you a fellow of honour's
# service.
#
# Second Servant:
# And, indeed, you mean the like; for you are
# a gentleman by your service.
#
# First Servant:
# I know it well. If you would so to offend
# him, you should have sworn your oath of service to me:
# for I am the physician, sir.
#
# First Servant:
# Yes, sir.
#
# MENENIUS:
# If any man in sight, or in the army,
# shall be consorted with any of you which--
# in this town he shall be the man for the common army;
# on which service, which is your right, that you shall have,
# but to go to this gentleman.
#
# Third Servant:
# And he shall do his duty,
# and have the honour of telling the stories
# He hath told me that he can keep them alive
# To come to you, to give the tale to you,
# that you shall have the honour which you have.
#
# First Servant:
# My god! how dare you tell the tale?
#
# MENENIUS:
# How dare you; to the most insulting denunciation.
#
# Second Servant:
# You know me, sir.
#
# First Servant:
# And, if you can say nothing else, that--
# Your worship to me, if thou art not a true gentleman's
# friend, I pray you, if you can in time have the
# entitlement of a physician, sir
# there's none you cannot, yet you have some service
#
#
# [210 | 498.29] loss=2.84 avg=3.12
# [220 | 521.66] loss=2.92 avg=3.11
# [230 | 545.01] loss=2.86 avg=3.10
# [240 | 568.34] loss=2.72 avg=3.08
# [250 | 591.70] loss=2.68 avg=3.06
# [260 | 615.05] loss=2.84 avg=3.05
# [270 | 638.38] loss=2.57 avg=3.03
# [280 | 661.73] loss=2.66 avg=3.02
# [290 | 685.08] loss=2.84 avg=3.01
# [300 | 708.49] loss=2.90 avg=3.00
# [310 | 731.95] loss=2.36 avg=2.98
# [320 | 755.37] loss=2.35 avg=2.96
# [330 | 778.76] loss=2.83 avg=2.95
# [340 | 802.13] loss=2.37 avg=2.93
# [350 | 825.53] loss=2.34 avg=2.91
# [360 | 848.99] loss=2.75 avg=2.91
# [370 | 872.42] loss=2.48 avg=2.89
# [380 | 895.85] loss=2.38 avg=2.88
# [390 | 919.26] loss=2.16 avg=2.86
# [400 | 942.69] loss=2.55 avg=2.85
# ======== SAMPLE 1 ========
# ROM!
#
# TRANIO:
# Is't for nothing.
#
# First Murderer:
# I pray you, tell a Sicilian the truth:
# A Sicilian knows a Sicilian; knows the Sicilians both;
# And it is not folly to presume that they
# Know each other.
#
# ALONSO:
# And know the Sicilian of you both.
#
# First Murderer:
# Yes, sir: yes, sir, sir; and one of the
# best of them all
# Is 'bout to be her mistress.
#
# ANGELO:
# I pray you, tell me one word or two of philosophy
# That we may all associate to effect an effect.
#
# TRANIO:
# And yet, sir, you shall be sorry we shall have
# No word or two of philosophy, to make an effect
# Upon our Baptistry: what shall be our Baptism?
#
# ANGELO:
# Sir, I pray you, tell me one word of philosophy
# That may bring you assurance in this business.
#
# ANGELO:
# I know not what philosophy hath to do with business;
# And in brief, as you must, I fear me to fall
# When I play the sceptre the sceptre.
#
# TRANIO:
# What philosophy have you in mind to play the sceptre?
#
# ANGELO:
# Ay, sir.
#
# TRANIO:
# Go ask this sir back.
#
# ANGELO:
# Sirrah, go ask him to bring you him back.
#
# TRANIO:
# Go ask him back with a dollar.
#
# ANGELO:
# Ay, sir.
#
# ANGELO:
# Go ask him to bring you him away.
#
# TRANIO:
# Go ask him to bring you him away too.
#
# ANGELO:
# I will find him again. But get you gone still.
# How now, sir! what is the business?
#
# TRANIO:
# Go play the priest.
#
# ANGELO:
# Sirrah play the priest now: I will show my prowess
# To help you.
#
# TRANIO:
# Sirrah, play the priest once more: here
# present yourself to be brought before the priest.
#
# ANGELO:
# Marry, mas, sir, I would be thy baw, to do this,
# that shall do this too.
#
# TRANIO:
# Go, go play the priest.
#
# ANGELO:
# Go play the priest again.
#
# TRANIO:
# Go, be ruled! play the priest then.
#
# ANGELO:
# Go, be ruled! play the priest now.
#
# TRANIO:
# Go, be ruled! play the priest now.
#
# ANGELO:
# Go, be ruled! play the priest now.
#
# TRANIO:
# Go, be ruled! play the priest now.
#
# ANGELO:
# Go, be ruled! Play the priest now.
#
# TRANIO:
# Go, be ruled! Play the priest now.
#
# ANGELO:
# Go, be ruled! Play the priest now.
#
# TRANIO:
# Play the priest.
#
# ANGELO:
# Play the priest!
#
# TRANIO:
# Take him hence, and get leave to speak.
#
# ANGELO:
# I desire to speak with you again, sir;
# And I will do it in a passing manner.
#
# TRANIO:
# Go play the priest, play the priest!
#
# ANGELO:
# How now, sir! by my troth
# My patience hath not been good.
#
# TRANIO:
# Go, give me leave to speak with you.
#
# ANGELO:
# I have not done well.
#
# TRANIO:
# Do as thou wilt; and speak the truth.
#
# ANGELO:
# I will not
# Speak to you again, sir; it is past time.
#
# TRANIO:
# The priest be gone.
#
# ANGELO:
# Pray God! what sport is here!
# Thy uncle Paul is thus sentenced!
# Thy father and thy wife charged with witchcraft
# Ere they could cure thy husband, for I
# Could not do them any good; though I knew that
# Thou wilt do them good.
#
# TRANIO:
# Go play the priest, be gone; there be found
# A most tedious business.
#
# ANGELO:
# I will not play the priest.
#
# TRANIO:
# Go play the priest!
#
# ANGELO:
# Thou shalt not play the priest.
#
# ANGELO:
# Thou shalt not play the priest.
#
# TRANIO:
# No, Tranio; go away
#
# [410 | 978.19] loss=2.52 avg=2.84
# [420 | 1001.55] loss=2.17 avg=2.82
# [430 | 1024.95] loss=2.53 avg=2.81
# [440 | 1048.39] loss=2.05 avg=2.79
# [450 | 1071.79] loss=2.34 avg=2.78
# [460 | 1095.14] loss=1.49 avg=2.74
# [470 | 1118.54] loss=1.68 avg=2.71
# [480 | 1141.97] loss=2.13 avg=2.70
# [490 | 1165.40] loss=1.71 avg=2.67
# [500 | 1188.82] loss=1.64 avg=2.65
# [510 | 1212.29] loss=2.05 avg=2.63
# [520 | 1235.75] loss=1.89 avg=2.61
# [530 | 1259.16] loss=1.65 avg=2.59
# [540 | 1282.56] loss=1.70 avg=2.57
# [550 | 1305.99] loss=1.80 avg=2.55
# [560 | 1329.43] loss=1.66 avg=2.53
# [570 | 1352.88] loss=1.55 avg=2.51
# [580 | 1376.33] loss=0.95 avg=2.47
# [590 | 1399.72] loss=1.39 avg=2.45
# [600 | 1423.13] loss=1.49 avg=2.43
# ======== SAMPLE 1 ========
# ; then that you cannot have more words with me,
# To help me calm myself.
#
# SICOPUS:
# To calm yourself?
#
# POMPHEY:
# Your mother, and yourself most well.
#
# LUCIO:
# You two look like one that will straight and open your lips.
#
# PETRUCHIO:
# I know my son well: he is from Baptista's sons;
# Lucentio and son to the most ancient,
# Of that incomparable birth, whose favour is recorded,
# His father's record, and the sufficiency of it:
# His age and fine nature, and not being touch'd,
# Could drink no remedy of any thing, though God's breath:
# But presently, as I am come to besiege you both,
# And will be with ready strength, as quickly as needs run,
# Call my services and learn to yourself what I intend
# To say.
#
# First Murderer:
# This then becomes me most: murder me first, my son
# My neighbour, and all that he claims, my lands,
# That by the land I am habited by law attach
# My dangerous pastime to the suspicion.
#
# DORCAS:
# So do you, Tranio.
#
# PETRUCHIO:
# I cannot do't without much violence.
#
# Nurse:
# He whom you have sworn to keep your peace,
# And to the best of your ability whatsoever,
# Will do just abuse to this vexatious suitor.
#
# PETRUCHIO:
# But, Lord Angelo, if you will,
# Say what you can; towards Baptista's sons,--
#
# VINCENTIO:
# I can swear it, sir: I know the cause of their coming.
#
# LUCIO:
# But, Tranio, I must confess I perceive you
# That way of the house, not to judge by what they
# have to say. Answer to these:
# If, in the morning, when the curfew is pronounced,
# My son Lucentio and myself shall be put to flight,
# The mayor and myself to prison,--
#
# PETRUCHIO:
# The mayor! I will do justice
# And, for my life, as swiftly apprehend him as
# I can from my cell, apprehend him alive.
# Right well; answer for what you can.
#
# LUCIO:
# I do; and I will believe it; for this is my man.
#
# PETRUCHIO:
# He cannot be released, sir, unless--
#
# VINCENTIO:
# The warrant's been issued, and we'll stay.
#
# LUCIO:
# 'Tis well borne up. What, shall we stay till Baptista comes?
#
# PETRUCHIO:
# Within an hour, Petruchio:
# I'll help you to your lodging. Father, I thank you;
# I did think you told fair justice.
#
# TRANIO:
# What, shall we stay till Baptista comes,
# For he came from Baptista's house?
#
# LUCIO:
# Within an hour, Tranio:
# I was sworn before, Baptista's son, that
# I should be sent for as early as Baptista's.
#
# PETRUCHIO:
# 'Tis well borne up:
# Let me desire you to hear some truth from your
# son: he will be your car; let me see him yourself.
#
# LUCIO:
# I am a subject of such trust, that I do entreat mine.
#
# PETRUCHIO:
# Father, I do not entreat you to come; I come too late.
#
# VOLUMNIA:
# Tranio, I will not sleep; I will dream it. Give me this letter.
#
# TRANIO:
# Hie haste, daughter: farewell, and have pity on't.
#
# VOLUMNIA:
# Now, sir, this letter, in the presence of Signior Lucentio,
# A kind benefice to your son, Signior Lucentio.
#
# PETRUCHIO:
# To bed, sir; to the door.
# SIR ANNE:
# Hic tiens spirituio in vestrum dignissimus tuum.
# Hic dignitatem dignitus iam dignitatem!
#
# LUCIO:
# So much for that.
#
# PETRUCHIO:
# Here comes Signior Lucentio.
# Away with the house: farewell!
#
# TRANIO:
# How now! what's that to you?
#
# LUCIO:
# It hath been a long while; but at length came home,
# And told me he was sent for to the Signior Lucentio.
#
# PETRUCHIO:
# I
#
# [610 | 1459.11] loss=0.91 avg=2.39
# [620 | 1482.53] loss=1.21 avg=2.37
# [630 | 1505.91] loss=1.20 avg=2.34
# [640 | 1529.36] loss=1.35 avg=2.32
# [650 | 1552.84] loss=1.28 avg=2.30
# [660 | 1576.26] loss=1.09 avg=2.28
# [670 | 1599.66] loss=1.39 avg=2.26
# [680 | 1623.05] loss=0.86 avg=2.23
# [690 | 1646.48] loss=1.11 avg=2.21
# [700 | 1669.91] loss=1.30 avg=2.19
# [710 | 1693.33] loss=0.92 avg=2.16
# [720 | 1716.75] loss=1.08 avg=2.14
# [730 | 1740.21] loss=0.85 avg=2.12
# [740 | 1763.68] loss=0.46 avg=2.09
# [750 | 1787.08] loss=0.64 avg=2.06
# [760 | 1810.47] loss=0.90 avg=2.04
# [770 | 1833.87] loss=0.91 avg=2.02
# [780 | 1857.29] loss=0.66 avg=1.99
# [790 | 1880.75] loss=0.48 avg=1.96
# [800 | 1904.14] loss=0.64 avg=1.94
# ======== SAMPLE 1 ========
#  so
# We are all but created chances, as our souls
# Do change forms, and the Creator o'erworn
# This hand.
#
# Second Murderer:
# I thought, your sons, he may come.
#
# LADY ANNE:
# I fear him not at all.
#
# First Murderer:
# Wisely play on his ghost, for he comes a-wooing.
#
# LADY ANNE:
# Good-wooing too, would he were living!
#
# First Murderer:
# What living being?
#
# LADY ANNE:
# I weep. I could sing and dance and do none of this.
# How now, my merry gentlemen! what news?
#
# First Murderer:
# Lord Angelo is arrived at Saint Luke's; the sea
# With all prerogative puts an end to all thought
# At once our heads: the ship hath aground perforce; the
# shearers, upon the western shore, hear the
# sea murmur and the thunder and the sea fling.
#
# LADY ANNE:
# Some aboard the ship faint at first. What news?
#
# First Murderer:
# It is at Saint Luke's, commanded by the
# great Vincent Angelo.
#
# LADY ANNE:
# Angelo's a mighty spirit indeed! Captain,
# you are invited to your ship Saint Luke's:
# There she shall rest, as it were some other ship's
# entertainment: of much revenue her hire; but that
# nothing can be done toward her satisfaction, but
# to make her superstaunch and fresher.
#
# Captain:
# I would not to have the honour to hear
# so freely of such a woman. I have got leave to go
# there, to shake hands with her, I think, and she shall
# feel me well.
#
# First Murderer:
# You may, captain, and there she shall sit, as it were nothing
# but a toy and her dainties may be smiled
# now on, now off: but in any deal upon her
# ship is far more my business. To-day within this
# time this year alone she's bankrupted her creditors:
# Her intents are not whether to sell her hence to-morrow,
# but to make insolvency of herself by herself.
#
# Second Murderer:
# Where is she?
#
# Captain:
# Here in this harbour, afore you, in this ship, commanded
# by Vincent Angelo.
#
# LADY ANNE:
# Good Captain, you have a happy party in hand:
# I'll persuade a wholesome appetite to come
# at a cheaper hour. This gentlemen's son,
# trust me, will he be call'd on to make a good
# reception this afternoon?
#
# First Murderer:
# Right, he may: it is thought his father is busy
# with a private matter: he shall not be doubted
# going to any place hither.
#
# LADY ANNE:
# What business is that, madam?
# Business indeed! the resolution it offers
# seems quite fit. To make this good, I think it may
# be considered. Sir, I have much desired your company--
#
# First Murderer:
# First, you have loved me most and have loved me
# especially to-day: and you, madam, have given in
# to many of the superficial promotions
# that you have to-day keep at home: some of them
# using these superficialities, outstrip
# you; some you would not consider before and those
# you would not consider to see. This afternoon for
# being unfashionable to the ladies and gentlemen
# that you bring in, I like to bed with you.
#
# Second Murderer:
# My good friends, I like to do it.
#
# First Murderer:
# I'll do it myself; you shall bear my
# warning. You shall find it much amiss to sit by and
# have fun with the ladies. As to the gentlemen, I am sure
# they are of good disposition. Sirs, get you out.
#
# ALONSO:
# I am your usual forthcoming person, having
# all the requisites to win the trust of the
# deliverant: you are welcome.
#
# First Murderer:
# I shall be contented with one that is. Sirs, let's
# have an early chat and an end our trouble.
#
# Second Murderer:
# I pray thee, good sweetie, be with thee.
#
# First:
# I am content; you are all well. This afternoon I
# put in some of my chamber's fittings, which are now
# flawless and do not flatter: some iron stands, some
# pipes, and others for the hot water. How now,
# it is your wife and her first son.
#
# Second:
# God in heaven bless them!
#
# First
#
# [810 | 1939.54] loss=0.83 avg=1.92
# [820 | 1962.98] loss=0.50 avg=1.89
# [830 | 1986.41] loss=0.69 avg=1.87
# [840 | 2009.81] loss=0.75 avg=1.85
# [850 | 2033.20] loss=0.74 avg=1.83
# [860 | 2056.60] loss=0.79 avg=1.82
# [870 | 2080.01] loss=0.63 avg=1.80
# [880 | 2103.43] loss=0.62 avg=1.78
# [890 | 2126.81] loss=0.69 avg=1.76
# [900 | 2150.23] loss=0.30 avg=1.73
# [910 | 2173.68] loss=0.37 avg=1.71
# [920 | 2197.13] loss=0.73 avg=1.69
# [930 | 2220.57] loss=0.41 avg=1.67
# [940 | 2244.01] loss=0.29 avg=1.65
# [950 | 2267.43] loss=0.26 avg=1.63
# [960 | 2290.80] loss=0.40 avg=1.61
# [970 | 2314.18] loss=0.31 avg=1.59
# [980 | 2337.59] loss=0.36 avg=1.57
# [990 | 2361.04] loss=0.35 avg=1.55
# [1000 | 2384.50] loss=0.32 avg=1.53
# Saving checkpoint/run1/model-1000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load the trained model

# %%
gpt2_simple.copy_checkpoint_to_gdrive(run_name='run1')

# %% [markdown]
# # **Generate Text From The Trained Model**

# %%
gpt2_simple.generate(sess, run_name='run1', length=300)
# Out:
# The good news is that every month we start a new "gold rush" in the industry. Starting with the MacBook Pro, Apple has gone so far as to finally start selling new and new models of the same product. The bad news is that that means the MacBook Pro is going to be out sooner rather than later.
#
# I know this is a lot of folks who are into the MacBook Pro, but I can't imagine that they're going to go there on a whim. It's unlikely that Apple will make a deal with a brand that hasn't made a deal with a brand that has only released one new MacBook Pro.
#
# Got a tip for the masses? Leave a comment below, and we'll add it to our newsletter next week!
#
# Related:
#
# Apple is Going to Ship the New MacBook Pro with A New Design
#
# Apple to Release New MacBook Pro Models
#
# Meet the new MacBook Pro
#
# iPhone 6 Plus, iPod Touch 5th Anniversary
#
# What's New in the Mac Pro
#
# That's about all that we know right now about the new MacBook Pro, which is scheduled to hit stores in March.
#
# Here are the specs for the new MacBook Pro:
#
# Display:
#
# Nvidia GeForce GTX 980 Ti
#
# Nvidia GeForce GTX 970
#
# Nvidia GeForce GTX 960
#
# Nvidia GeForce GTX 950
#
# Nvidia GeForce GTX 960
#
# Nvidia GeForce GTX 970
#
# Nvidia GeForce GTX 960

# %%
gpt2_simple.generate(sess)
# Out:
# If you have a lot of money, the only thing you have to ask yourself is how to pay for everything for you. If you don't have time to take care of your finances, there is no way to enjoy living your life.
#
# So what's the best way to pay for life? What are some ways that you can get rid of money and live better?
#
# 1) Take care of your finances.
#
# The first thing you need to do is give yourself time to take care of your finances.
#
# If you have just started a business, you know that you need to take care of your finances in regular time. You need to feel good about yourself and enjoy the company of others. You should also try to take care of your finances by the time you really get back to work or school.
#
# When you are working every day, you might be taking care of your finances by the time you get to work. It is easy to forget that you have to take care of your finances and it is often impossible to do so because you are only looking for a day job and you don't have time to go to work. It is very difficult to find the time to do much of anything other than take care of your finances.
#
# In the meantime, you should be looking for a place to start and try to get started. You can do this by going to a bank and asking for a deposit and then going to a bank and asking for a line of credit. You will now be able to pay for your time and you will be able to pay for yourself.
#
# 2) Take care of your finances.
#
# You have to take care of your finances. You need to take care of everything that comes with life. You need to take care of your finances because life is an important part of your life. So do not forget that life is an important part of your life. In fact, it is your life.
#
# There are many things that you can do to take care of your finances.
#
# Take care of your money.
#
# Many people don't understand that your money is important. If you don't have money for yourself, you will not be happy.
#
# Take care of your needs.
#
# When you see a problem, you think about how to solve it. You can make a statement that says that something is wrong with your life, but this is not what you want to say.
#
# Take care of your time.
#
# Time is important. Like life, it does not have to be stressful. You can put your heart and soul into managing your time.
#
# Take care of your money.
#
# Money is important. It is what you have and it is what you need. If your money is good, it is good enough to pay for your expenses.
#
# Take care of your money.
#
# Money is a part of life. Money is important because it is what you have.
#
# Take care of your money.
#
# You can do this by taking care of your finances.
#
# If you have money to pay for things, to pay for your expenses, to pay for your education, to pay for your school, to pay for your doctor's office, to pay for your school, to pay for your school's food, to pay for your school's electricity, to pay for your school's water, to pay for your school's water supply, to pay for your school's electrical, to pay for your school's electricity supply, to pay for your school's medical supplies, to pay for your school's medicines, to pay for your school's house supplies, to pay for your school's medical supplies, to pay for your school's hospital supplies, to pay for your school's medicines, to pay for your school's prescriptions, to pay for your school's books, to pay for your school's books, to pay for your school's supplies, to pay for your money, to pay for your whole life's worth.
#
# Buy a house.
#
# If you want a house, you can buy it. You can buy a house for yourself, for your family, or for a friend. If you want to buy a house for a friend, you can buy a house for yourself.
#
# Take care of your finances.
#
# You have to take care of your finances. If you don't have money for yourself, you will not be happy.
#
# Take care of your money.
#
# When you see a problem, you think about how to solve it. You can make a statement that says that something is wrong with your life, but this is not what you want to say.
#
# Take care of your money.
#
# Money is a part of life. Money is important because it is what you have.
#
# Take care of your money.
#
# You can do this by taking care of your finances.
#
# When you see a problem, you think about how to solve it. You can make
